# %%
# Install the latest release of Haystack in your own environment
#! pip install farm-haystack

# Install the latest master of Haystack
# !pip install --upgrade pip
# !pip install git+https://github.com/deepset-ai/haystack.git#egg=farm-haystack[colab]

# Install  pygraphviz
# !apt install libgraphviz-dev
# !pip install pygraphviz

# In Colab / No Docker environments: Start Elasticsearch from source
! wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.9.2-linux-x86_64.tar.gz -q
! tar -xzf elasticsearch-7.9.2-linux-x86_64.tar.gz
! chown -R daemon:daemon elasticsearch-7.9.2

import os
from subprocess import Popen, PIPE, STDOUT

es_server = Popen(
    ["elasticsearch-7.9.2/bin/elasticsearch"], stdout=PIPE, stderr=STDOUT, preexec_fn=lambda: os.setuid(1)  # as daemon
)
# wait until ES has started
! sleep 30
# Out:
# Requirement already satisfied: pip in c:\programdata\anaconda3\lib\site-packages (22.0.4)
# Error processing line 7 of c:\programdata\anaconda3\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "c:\programdata\anaconda3\lib\site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\programdata\anaconda3\lib\site-packages)
# Collecting farm-haystack[colab]
#   Cloning https://github.com/deepset-ai/haystack.git to c:\users\janet\appdata\local\temp\pip-install-rykfbo6a\farm-haystack_467676357c82496cb06a9fdaca48aff0
#   Resolved https://github.com/deepset-ai/haystack.git to commit 85571cdd15f1c9592cf28121187ffef7d4827f83
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\lib\site-packages (from farm-haystack[colab]) (4.11.2)
# Collecting seqeval
#   Using cached seqeval-1.2.2-py3-none-any.whl
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from farm-haystack[colab]) (4.62.3)
# Requirement already satisfied: pydantic in c:\programdata\anaconda3\lib\site-packages (from farm-haystack[colab]) (1.8.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from farm-haystack[colab]) (2.25.1)
# Collecting tika
#   Using cached tika-1.24-py3-none-any.whl
# Collecting sentence-transformers>=0.4.0
#   Using cached sentence_transformers-2.2.0-py3-none-any.whl
# Requirement already satisfied: torch<1.11,>1.9 in c:\programdata\anaconda3\lib\site-packages (from farm-haystack[colab]) (1.10.1)
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (from farm-haystack[colab]) (3.4.5)
# Collecting elasticsearch<=7.10,>=7.7
#   Using cached elasticsearch-7.10.0-py2.py3-none-any.whl (321 kB)
# Collecting transformers==4.13.0
#   Using cached transformers-4.13.0-py3-none-any.whl (3.3 MB)
# Collecting mlflow<=1.13.1
#   Using cached mlflow-1.13.1-py3-none-any.whl (14.1 MB)
# Collecting azure-ai-formrecognizer==3.2.0b2
#   Using cached azure_ai_formrecognizer-3.2.0b2-py2.py3-none-any.whl (219 kB)
# Collecting scikit-learn>=1.0.0
#   Using cached scikit_learn-1.0.2-cp37-cp37m-win_amd64.whl (7.1 MB)
# Collecting azure-core<1.23
#   Using cached azure_core-1.22.1-py3-none-any.whl (178 kB)
# Collecting langdetect
#   Using cached langdetect-1.0.9-py3-none-any.whl
# Collecting mmh3
#   Using cached mmh3-3.0.0-cp37-cp37m-win_amd64.whl (15 kB)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from farm-haystack[colab]) (2.3)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from farm-haystack[colab]) (1.3.5)
# Requirement already satisfied: more-itertools in c:\programdata\anaconda3\lib\site-packages (from farm-haystack[colab]) (7.2.0)
# Collecting python-docx
#   Using cached python_docx-0.8.11-py3-none-any.whl
# Collecting dill
#   Using cached dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting elastic-apm
#   Using cached elastic_apm-6.8.1-cp37-cp37m-win_amd64.whl
# Collecting quantulum3
#   Using cached quantulum3-0.7.10-py3-none-any.whl (10.7 MB)
# Collecting scipy>=1.3.2
#   Using cached scipy-1.7.3-cp37-cp37m-win_amd64.whl (34.1 MB)
# Collecting grpcio==1.43.0
#   Using cached grpcio-1.43.0-cp37-cp37m-win_amd64.whl (3.3 MB)
# Requirement already satisfied: six>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack[colab]) (1.16.0)
# Collecting azure-common~=1.1
#   Using cached azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting msrest>=0.6.21
#   Using cached msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Requirement already satisfied: sacremoses in c:\programdata\anaconda3\lib\site-packages (from transformers==4.13.0->farm-haystack[colab]) (0.0.47)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers==4.13.0->farm-haystack[colab]) (2022.1.18)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from transformers==4.13.0->farm-haystack[colab]) (5.1.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\programdata\anaconda3\lib\site-packages (from transformers==4.13.0->farm-haystack[colab]) (0.10.3)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from transformers==4.13.0->farm-haystack[colab]) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from transformers==4.13.0->farm-haystack[colab]) (1.19.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from transformers==4.13.0->farm-haystack[colab]) (3.0.12)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\programdata\anaconda3\lib\site-packages (from transformers==4.13.0->farm-haystack[colab]) (0.4.0)
# Requirement already satisfied: urllib3<2,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from elasticsearch<=7.10,>=7.7->farm-haystack[colab]) (1.25.11)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from elasticsearch<=7.10,>=7.7->farm-haystack[colab]) (2019.9.11)
# Collecting prometheus-flask-exporter
#   Using cached prometheus_flask_exporter-0.19.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\lib\site-packages (from mlflow<=1.13.1->farm-haystack[colab]) (0.3)
# Collecting waitress
#   Using cached waitress-2.1.0-py3-none-any.whl (56 kB)
# Collecting sqlparse>=0.3.1
#   Using cached sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Collecting alembic<=1.4.1
#   Using cached alembic-1.4.1-py2.py3-none-any.whl
# Collecting docker>=4.0.0
#   Using cached docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting azure-storage-blob>=12.0.0
#   Using cached azure_storage_blob-12.10.0-py3-none-any.whl (346 kB)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\lib\site-packages (from mlflow<=1.13.1->farm-haystack[colab]) (2.8.0)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from mlflow<=1.13.1->farm-haystack[colab]) (1.2.2)
# Requirement already satisfied: click>=7.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow<=1.13.1->farm-haystack[colab]) (8.0.4)
# Requirement already satisfied: protobuf>=3.6.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow<=1.13.1->farm-haystack[colab]) (3.19.4)
# Collecting querystring-parser
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: gitpython>=2.1.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow<=1.13.1->farm-haystack[colab]) (3.1.27)
# Requirement already satisfied: Flask in c:\programdata\anaconda3\lib\site-packages (from mlflow<=1.13.1->farm-haystack[colab]) (1.1.1)
# Requirement already satisfied: sqlalchemy in c:\programdata\anaconda3\lib\site-packages (from mlflow<=1.13.1->farm-haystack[colab]) (1.3.9)
# Collecting databricks-cli>=0.8.7
#   Using cached databricks_cli-0.16.4-py3-none-any.whl
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->farm-haystack[colab]) (2.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->farm-haystack[colab]) (3.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->farm-haystack[colab]) (0.13.2)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: torchvision in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers>=0.4.0->farm-haystack[colab]) (0.11.2)
# Requirement already satisfied: sentencepiece in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers>=0.4.0->farm-haystack[colab]) (0.1.96)
# Requirement already satisfied: typing_extensions in c:\programdata\anaconda3\lib\site-packages (from torch<1.11,>1.9->farm-haystack[colab]) (3.10.0.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->farm-haystack[colab]) (0.4.1)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata->farm-haystack[colab]) (0.6.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\programdata\anaconda3\lib\site-packages (from networkx->farm-haystack[colab]) (4.4.0)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->farm-haystack[colab]) (2019.3)
# Requirement already satisfied: lxml>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from python-docx->farm-haystack[colab]) (4.4.1)
# Collecting num2words
#   Using cached num2words-0.5.10-py3-none-any.whl (101 kB)
# Collecting inflect
#   Using cached inflect-5.4.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tika->farm-haystack[colab]) (41.4.0)
# Collecting python-editor>=0.3
#   Using cached python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting Mako
#   Using cached Mako-1.2.0-py3-none-any.whl (78 kB)
# Requirement already satisfied: cryptography>=2.1.4 in c:\programdata\anaconda3\lib\site-packages (from azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack[colab]) (2.7)
# Requirement already satisfied: tabulate>=0.7.7 in c:\programdata\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow<=1.13.1->farm-haystack[colab]) (0.8.9)
# Collecting pywin32==227
#   Using cached pywin32-227-cp37-cp37m-win_amd64.whl (9.1 MB)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\programdata\anaconda3\lib\site-packages (from docker>=4.0.0->mlflow<=1.13.1->farm-haystack[colab]) (1.2.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack[colab]) (4.0.9)
# Collecting isodate>=0.6.0
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting requests-oauthlib>=0.5.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->transformers==4.13.0->farm-haystack[colab]) (2.4.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\programdata\anaconda3\lib\site-packages (from Flask->mlflow<=1.13.1->farm-haystack[colab]) (0.16.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\programdata\anaconda3\lib\site-packages (from Flask->mlflow<=1.13.1->farm-haystack[colab]) (2.10.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from Flask->mlflow<=1.13.1->farm-haystack[colab]) (1.1.0)
# Collecting docopt>=0.6.2
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\lib\site-packages (from prometheus-flask-exporter->mlflow<=1.13.1->farm-haystack[colab]) (0.7.1)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from torchvision->sentence-transformers>=0.4.0->farm-haystack[colab]) (9.0.1)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack[colab]) (1.0.1)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack[colab]) (1.12.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack[colab]) (5.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask->mlflow<=1.13.1->farm-haystack[colab]) (1.1.1)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack[colab]) (2.19)
# Building wheels for collected packages: farm-haystack
#   Building wheel for farm-haystack (pyproject.toml): started
#   Building wheel for farm-haystack (pyproject.toml): finished with status 'done'
#   Created wheel for farm-haystack: filename=farm_haystack-1.2.1rc0-py3-none-any.whl size=429648 sha256=96deacbc92681518a4ec725cdf71d478e2525159748e872064bd9c577d953584
#   Stored in directory: C:\Users\Janet\AppData\Local\Temp\pip-ephem-wheel-cache-8iiqn6yd\wheels\a7\05\3b\9b33368d9af06a39f8e6af2e97fa2af876e893ade323cfc2c9
# Successfully built farm-haystack
# Installing collected packages: pywin32, python-editor, mmh3, docopt, azure-common, waitress, threadpoolctl, sqlparse, scipy, querystring-parser, python-docx, oauthlib, num2words, langdetect, isodate, inflect, grpcio, elasticsearch, elastic-apm, dill, tika, scikit-learn, requests-oauthlib, quantulum3, docker, azure-core, seqeval, msrest, Mako, databricks-cli, azure-storage-blob, azure-ai-formrecognizer, alembic, transformers, prometheus-flask-exporter, sentence-transformers, mlflow, farm-haystack
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 223
#     Uninstalling pywin32-223:
#       Successfully uninstalled pywin32-223
#   Rolling back uninstall of pywin32
#   Moving to c:\programdata\anaconda3\lib\site-packages\__pycache__\pythoncom.cpython-37.pyc
#    from C:\Users\Janet\AppData\Local\Temp\pip-uninstall-ladtw522\pythoncom.cpython-37.pyc
#   Moving to c:\programdata\anaconda3\lib\site-packages\adodbapi
#    from c:\programdata\anaconda3\lib\site-packages\~dodbapi
#   Moving to c:\programdata\anaconda3\lib\site-packages\isapi
#    from c:\programdata\anaconda3\lib\site-packages\~sapi
#   Moving to c:\programdata\anaconda3\lib\site-packages\pythoncom.py
#    from C:\Users\Janet\AppData\Local\Temp\pip-uninstall-2wjqajpf\pythoncom.py
#   Moving to c:\programdata\anaconda3\lib\site-packages\pythonwin
#    from c:\programdata\anaconda3\lib\site-packages\~ythonwin
#   Moving to c:\programdata\anaconda3\lib\site-packages\pywin32-223-py3.7.egg-info
#    from c:\programdata\anaconda3\lib\site-packages\~ywin32-223-py3.7.egg-info
#   Moving to c:\programdata\anaconda3\lib\site-packages\win32\lib\
#    from c:\programdata\anaconda3\lib\site-packages\win32\~ib
#   Moving to c:\programdata\anaconda3\lib\site-packages\win32com
#    from c:\programdata\anaconda3\lib\site-packages\~in32com
#   Moving to c:\programdata\anaconda3\lib\site-packages\win32comext
#    from c:\programdata\anaconda3\lib\site-packages\~in32comext
# Error processing line 7 of c:\programdata\anaconda3\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "c:\programdata\anaconda3\lib\site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\programdata\anaconda3\lib\site-packages)
#   Running command git clone --filter=blob:none --quiet https://github.com/deepset-ai/haystack.git 'C:\Users\Janet\AppData\Local\Temp\pip-install-rykfbo6a\farm-haystack_467676357c82496cb06a9fdaca48aff0'
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (c:\programdata\anaconda3\lib\site-packages)
#   WARNING: No metadata found in c:\programdata\anaconda3\lib\site-packages
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\Lib\\site-packages\\pywin32_system32\\pywintypes37.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\programdata\anaconda3\lib\site-packages)
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from haystack.utils import print_answers, fetch_archive_from_http, convert_files_to_dicts, clean_wiki_text, launch_es
from haystack.pipelines import Pipeline, RootNode
from haystack.document_stores import ElasticsearchDocumentStore
from haystack.nodes import (
    ElasticsearchRetriever,
    DensePassageRetriever,
    FARMReader,
    TransformersQueryClassifier,
    SklearnQueryClassifier,
)

# Download and prepare data - 517 Wikipedia articles for Game of Thrones
doc_dir = "data/article_txt_got"
s3_url = "https://s3.eu-central-1.amazonaws.com/deepset.ai-farm-qa/datasets/documents/wiki_gameofthrones_txt.zip"
fetch_archive_from_http(url=s3_url, output_dir=doc_dir)

# convert files to dicts containing documents that can be indexed to our datastore
got_dicts = convert_files_to_dicts(dir_path=doc_dir, clean_func=clean_wiki_text, split_paragraphs=True)

# Initialize DocumentStore and index documents
launch_es()
document_store = ElasticsearchDocumentStore()
document_store.delete_documents()
document_store.write_documents(got_dicts)

# Initialize Sparse retriever
es_retriever = ElasticsearchRetriever(document_store=document_store)

# Initialize dense retriever
dpr_retriever = DensePassageRetriever(document_store)
document_store.update_embeddings(dpr_retriever, update_existing_embeddings=False)

reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2")

# %% [markdown]
# ## Question vs Statement Classifier

# %%
# Here we build the pipeline
transformer_question_classifier = Pipeline()
transformer_question_classifier.add_node(component=dpr_retriever, name="DPRRetriever", inputs=["Query"])
transformer_question_classifier.add_node(
    component=TransformersQueryClassifier(model_name_or_path="shahrukhx01/question-vs-statement-classifier"),
    name="QueryClassifier",
    inputs=["DPRRetriever"],
)
transformer_question_classifier.add_node(component=reader, name="QAReader", inputs=["QueryClassifier.output_1"])
transformer_question_classifier.draw("question_classifier.png")

# Run only the QA reader on the question query
res_1 = transformer_question_classifier.run(query="Who is the father of Arya Stark?")
print("DPR Results" + "\n" + "=" * 15)
print_answers(res_1, details="minimum")

# Show only DPR results
res_2 = transformer_question_classifier.run(query="Arya Stark was the daughter of a Lord.")
print("ES Results" + "\n" + "=" * 15)
print_answers(res_2, details="minimum")

# %%
# Here we create the question vs statement query classifier
from haystack.pipelines import TransformersQueryClassifier

queries = [
    "Lord Eddard was the father of Arya Stark.",
    "Jon Snow was filmed in United Kingdom.",
    "who is the father of arya stark?",
    "Which country was jon snow filmed in?",
    "Did Pope Francis Just Pave the Way for Women Priests?"
]

question_classifier = TransformersQueryClassifier(model_name_or_path="shahrukhx01/question-vs-statement-classifier")

for query in queries:
    result = question_classifier.run(query=query)
    if result[1] == "output_1":
        category = "question"
    else:
        category = "statement"

    print(f"Query: {query}, raw_output: {result}, class: {category}")

# %% [markdown]
# apply to our dataframe

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Clean CS224N folder

# %%
import pandas as pd
df = pd.read_csv('SCBAll.csv')
#Check what preprocessing (Beicheng uses pruned data set)
df = df.dropna() #remove nones
df['summary'] = df['summary'].str.replace('#StopClickbait', '')
df

# %%
df['classifier']=''
for ind in range(786):
    try:
      query = df['title'][ind]
      result = question_classifier.run(query=query)
      if result[1] == "output_1":
          category = "question"
      else:
          category = "statement"
      df['classifier'][ind] = category
    except:
      pass

# %%
df

# %%
df.to_excel("output_class.xlsx")

# %%
df['classifier'].value_counts()

# %%
print("statements= "+str(590/(590+141)))
print("question= "+str(141/(590+141)))

# %% [markdown]
# See if extr or abs performs better for which task!

# %%
# the longformer model i saved as output_ext excel file
longformer_df = pd.read_excel(r'output_ext.xlsx')

# %%
longformer_df['classifier']=''
for ind in range(786):
    try:
      query = longformer_df['title'][ind]
      result = question_classifier.run(query=query)
      if result[1] == "output_1":
          category = "question"
      else:
          category = "statement"
      longformer_df['classifier'][ind] = category
    except:
      pass

# %%
longformer_df

# %%
longformer_df = longformer_df.dropna()
longformer_df_S = longformer_df[longformer_df['classifier'] == "statement"]
longformer_df_Q = longformer_df[longformer_df['classifier'] == "question"]

# %%
print(len(longformer_df_S))
print(len(longformer_df_Q))

# %% [markdown]
# BERTscore for longformer_df_S and longformer_df_Q

# %%
# !pip install bert-score
# !pip install torch

# %%
from bert_score import score
import numpy as np
import torch

# %%
tmp = longformer_df_S
Pb, Rb, Fb = score([str(i) for i in tmp['summary'].tolist()], [str(i) for i in tmp["ext answer val_Sq1"].tolist()], lang='en')
print("Longformer Statements")
print("Precision: "+str(torch.mean(Pb)))
print("Recall: "+str(torch.mean(Rb[~torch.isnan(Rb)])))
print("Fbert: "+str(torch.mean(Fb)))

tmp = longformer_df_Q
Pb, Rb, Fb = score([str(i) for i in tmp['summary'].tolist()], [str(i) for i in tmp["ext answer val_Sq1"].tolist()], lang='en')
print("Longformer Questions")
print("Precision: "+str(torch.mean(Pb)))
print("Recall: "+str(torch.mean(Rb[~torch.isnan(Rb)])))
print("Fbert: "+str(torch.mean(Fb)))

# %% [markdown]
# Rouge scores Longformer Q and S

# %%
# !pip install rouge/requirements.txt
# !pip install rouge-score

# %%
import numpy as np
from rouge_score import rouge_scorer

tmp = longformer_df_S
# a list of the hypothesis documents
hyp = [str(i) for i in tmp['summary'].tolist()]
# a list of the references documents
ref = [str(i) for i in tmp['ext answer val_Sq1'].tolist()]
for ind in ['1','2','L']:
  print("Rouge"+ind)
  scorer = rouge_scorer.RougeScorer(['rouge'+ind])
  results = {'precision': [], 'recall': [], 'fmeasure': []}
  for (h, r) in zip(hyp, ref):
      score = scorer.score(h, r)
      precision, recall, fmeasure = score['rouge'+ind]
      results['precision'].append(precision)
      results['recall'].append(recall)
      results['fmeasure'].append(fmeasure)
  print("results['precision']"+ str(np.mean(results['precision'])))
  print("results['recall']"+ str(np.mean(results['recall'])))
  print("results['fmeasure']"+ str(np.mean(results['fmeasure'])))

tmp = longformer_df_Q
# a list of the hypothesis documents
hyp = [str(i) for i in tmp['summary'].tolist()]
# a list of the references documents
ref = [str(i) for i in tmp['ext answer val_Sq1'].tolist()]
for ind in ['1','2','L']:
  print("Rouge"+ind)
  scorer = rouge_scorer.RougeScorer(['rouge'+ind])
  results = {'precision': [], 'recall': [], 'fmeasure': []}
  for (h, r) in zip(hyp, ref):
      score = scorer.score(h, r)
      precision, recall, fmeasure = score['rouge'+ind]
      results['precision'].append(precision)
      results['recall'].append(recall)
      results['fmeasure'].append(fmeasure)
  print("results['precision']"+ str(np.mean(results['precision'])))
  print("results['recall']"+ str(np.mean(results['recall'])))
  print("results['fmeasure']"+ str(np.mean(results['fmeasure'])))

# %% [markdown]
# # do it for T5 epoch 20

# %%
import pandas as pd
df = pd.read_csv('predictions.csv')

# %%
t5_df =df
t5_df

# %%
t5_df['classifier']=''
for ind in range(786):
    try:
      query = t5_df['title'][ind]
      result = question_classifier.run(query=query)
      if result[1] == "output_1":
          category = "question"
      else:
          category = "statement"
      longformer_df['classifier'][ind] = category
    except:
      pass
